# %% [markdown]
# # Guía 2
#
# ## Ejercicio 1.2
# Tiro un dado 2 veces, quiero la distribución de la suma de los resultados:
#
# $X$:"resultado del dado 1",   $Y$:"resultado del dado 2,   $W$: "suma de los dos resultados"
#
# Hago una tabla de doble entrada donde en el interior anoto el valor de w correspondiente al par (x,y).
#
# | y\|x | 1    | 2    | 3    | 4    | 5    | 6    |
# | ---- | ---- | ---- | ---- | ---- | ---- | ---- |
# | 1    | 2    | 3    | 4    | 5    | 6    | 7    |
# | 2    | 3    | 4    | 5    | 6    | 7    | 8    |
# | 3    | 4    | 5    | 6    | 7    | 8    | 9    |
# | 4    | 5    | 6    | 7    | 8    | 9    | 10   |
# | 5    | 6    | 7    | 8    | 9    | 10   | 11   |
# | 6    | 7    | 8    | 9    | 10   | 11   | 12   |
#
#
# Para calcular la función de probabilidad de $W$ recuerdo que estoy en un espacio equiprobable y por lo tanto $\mathbb{P}(X=x , Y=y) = 1/36,\quad x = 1,2,...,6,\ y = 1,2,...,6$.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
# simulo 1000 tiradas de un dad0 dos veces
xy = np.random.randint(1,7,size=(1000,2))  
# sumo los resultados de cada dado para generar 1000 observaciones de z
z = np.sum(xy,axis=1)

# grafico la función de proba estimada
plt.bar(np.arange(1, np.max(z)+1), np.bincount(z)[1:]) 
# bincount me cuenta cuantos caen desde 0 hasta el max valor obs del vector. Aca 0 no es un valor posible, asi que lo quito
# Out:
# <BarContainer object of 12 artists>

# %% [markdown]
# # Ejercicio 2.2
# Hallar la distribución del mínimo de $n$ v.a. exponenciales independientes de parámetro $\lambda$.
# $F_Y(y) = \mathbb{P}(Y\leq y) = \mathbb{P}(\min(X_1,\ldots,x_n) \leq y) = 1 - \mathbb{P}(\min(X_1,\ldots, x_n) > y)$
# desde acá se puede seguir parecido al ejemplo que vimos en clase donde calculamos la distribución del máximo de uniformes.
#
# Se concluye que $Y\sim \exp(\lambda n)$
#
# A continuación simulo para $\lambda = 5$ y $n=6$. Probar con distintos valores.
# Bonus: que pasa si $X_i \sim \mathcal{E}(\lambda_i)$, es decir siguen siendo exponenciales independientes pero ahora de distinto parámetro

# %%
# genero 1000 realizaciones de 6 exponenciales de parámetro 5
x = np.random.exponential(scale=1/5, size=(1000,6))
y = np.min(x, axis=1) # calculo el mininmo de las 6 exp
sns.histplot(y, kde=True, stat='density') # grafico el hist y kde
# Y~exp(lambda*6). Superpongo la densidad verdadera y comparo
sns.lineplot(x=np.linspace(0,0.5,1000),y=stats.expon.pdf(np.linspace(0,0.5,1000), scale=1/(5*6)), color='C1')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## Ejercicio 2.3
# Tengo $X,\ Y \overset{i.i.d}{\sim} \mathcal{E}(\lambda)$ y defino $V=X+Y$, $W=X/(X+Y)$.
#
# Luego, $g_1(x,y) = x+y$ y $g_2(x,y) = x/(x+y)$.
#
# Las inversas resultan:
# $x = g^{-1}_1(v,w) = vw$, $y = g^{-1}_2(v,w) = v(1-w)$.
#
# **Nota** $\left.{\underbrace{\left|\begin{matrix}\frac{\partial g_1}{\partial x} & \frac{\partial g_1}{\partial y}\\
# \frac{\partial g_2}{\partial x} & \frac{\partial g_2}{\partial y}\end{matrix} \right|}_{|J|}}^{-1} \right|_{x= g^{-1}_1(v,w), y = g^{-1}_2(v,w)}= \underbrace{\left|\begin{matrix}\frac{\partial g^{-1}_1}{\partial v} & \frac{\partial g_1^{-1}}{\partial w}\\
# \frac{\partial g_2^{-1}}{\partial v} & \frac{\partial g_2^{-1}}{\partial w}\end{matrix} \right|}_{|J^{-1}|}$
#
# En este caso es mucho más fácil calcular $J^{-1}$: $J^{-1}= \left[\begin{matrix} w & v \\ 1-w & -v \end{matrix}\right] \Rightarrow |J^{-1}| = v$
#
# La función de densidad de $V,W$ resulta:
# $$f_{V,W}(v,w) = \left.f_{X,Y}(x,y)\right|_{x= \frac{vw}{w+1}, y=\frac{v}{w+1}} |J^{-1}|= v \lambda^2 e^{-\lambda v} \mathbf{I}\{v>0\}\mathbf{I}\{0<w<1\}$$
#
# Nota: La transformación de las indicadoras se observa relativamente fácil a partir de la definición de $V$ y $W$ y que $X$, $Y$ son variables positivas.
#
# Voy a simular suponiendo $\lambda = 1/5$. Recordar que el parámetro de la exponencial que reciben tanto numpy como scipy es $\texttt{scale}=1/\lambda$.

# %%
xy = np.random.exponential(5, size=(5000,2))
v = xy.sum(axis=1) 
w = xy[:,0]/v

# %% [markdown]
# Para graficar la conjunta podemos usar los gráficos de contorne de seaborn, que nos dan la conjuna y las marginales en un único gráfico [Visualizacion de distribuciones usando Seaborn](https://seaborn.pydata.org/tutorial/distributions.html)

# %%
p = sns.jointplot(x=v, y=w,   kind="kde" )
p.ax_marg_x.plot(np.linspace(0,100,1000), stats.gamma.pdf(np.linspace(0,100,1000),a=2,scale=5), color='r')
p.ax_marg_y.plot( np.ones([1000,1]), np.linspace(0,1,1000), color='r')
