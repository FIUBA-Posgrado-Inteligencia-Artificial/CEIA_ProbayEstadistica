# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data = pd.read_csv('../Islander_data.csv')
data.head()
# Out:
#   first_name last_name  age Happy_Sad_group  Dosage Drug  Mem_Score_Before  \
# 0    Bastian  Carrasco   25               H       1    A              63.5
# 1       Evan  Carrasco   52               S       1    A              41.6
# 2  Florencia  Carrasco   29               H       1    A              59.7
# 3      Holly  Carrasco   50               S       1    A              51.7
# 4     Justin  Carrasco   52               H       1    A              47.0
#
#    Mem_Score_After  Diff
# 0             61.2  -2.3
# 1             40.7  -0.9
# 2             55.1  -4.6
# 3             51.2  -0.5
# 4             47.1   0.1

# %%
x = data.Diff

# %%
sns.ecdfplot(x)
# Out:
# <AxesSubplot:xlabel='Diff', ylabel='Proportion'>

# %%
plt.hist(x, bins=30, density=True)
# Out:
# (array([0.0016948 , 0.        , 0.        , 0.        , 0.        ,
#         0.        , 0.0033896 , 0.        , 0.0050844 , 0.0033896 ,
#         0.0220324 , 0.0220324 , 0.04914921, 0.05592841, 0.05592841,
#         0.04067521, 0.0152532 , 0.0118636 , 0.0118636 , 0.0067792 ,
#         0.0135584 , 0.0033896 , 0.0067792 , 0.        , 0.0016948 ,
#         0.        , 0.0033896 , 0.        , 0.        , 0.0016948 ]),
#  array([-40.4 , -37.42, -34.44, -31.46, -28.48, -25.5 , -22.52, -19.54,
#         -16.56, -13.58, -10.6 ,  -7.62,  -4.64,  -1.66,   1.32,   4.3 ,
#           7.28,  10.26,  13.24,  16.22,  19.2 ,  22.18,  25.16,  28.14,
#          31.12,  34.1 ,  37.08,  40.06,  43.04,  46.02,  49.  ]),
#  <BarContainer object of 30 artists>)

# %%
sns.histplot(x, stat='density')
# Out:
# <AxesSubplot:xlabel='Diff', ylabel='Density'>

# %%
sns.kdeplot(x)
# Out:
# <AxesSubplot:xlabel='Diff', ylabel='Density'>

# %%
sns.histplot(x, )
