# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sales = pd.read_csv('advertising.csv')
sales.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
newspaper = sales.Newspaper
len(newspaper)
# Out:
# 200

# %%
sns.ecdfplot(newspaper)
# Out:
# <Axes: xlabel='Newspaper', ylabel='Proportion'>

# %%
sns.histplot(newspaper, stat='density')
# Out:
# <Axes: xlabel='Newspaper', ylabel='Density'>

# %%
sns.kdeplot(newspaper)
# Out:
# <Axes: xlabel='Newspaper', ylabel='Density'>

# %% [markdown]
# # Intervalos de confianza

# %%
from scipy import stats
from numpy import sqrt
import numpy as np
import matplotlib.pyplot as plt

# %%
q95=stats.norm.ppf(0.95)

# %%
np.random.seed(0)
x = stats.norm.rvs(size=20, loc=3, scale=2)
x
# Out:
# array([6.52810469, 3.80031442, 4.95747597, 7.4817864 , 6.73511598,
#        1.04544424, 4.90017684, 2.69728558, 2.7935623 , 3.821197  ,
#        3.28808714, 5.90854701, 4.52207545, 3.24335003, 3.88772647,
#        3.66734865, 5.98815815, 2.58968347, 3.6261354 , 1.29180852])

# %%
x.mean() - q95*2/sqrt(20)
# Out:
# 2.701239957352362

# %%
x = np.linspace(-4,4,1000)

# %%
plt.plot(x, stats.norm.pdf(x), color='C0')
plt.plot(x, stats.t.pdf(x,df=1), color='C1')
plt.plot(x, stats.t.pdf(x,df=5), color='C2')
plt.plot(x, stats.t.pdf(x,df=10), color='C3')
plt.plot(x, stats.t.pdf(x,df=30), color='C4')

# %%
t995= stats.t.ppf(0.975,df=20)
t995
# Out:
# 2.085963447265837

# %%
print(f"Intervalo de confianza: ({x.mean()-t995*x.std()/sqrt(20)},{x.mean()+t995*x.std()/sqrt(20)} )")
# Out:
# Intervalo de confianza: (3.3455581253275666,4.931780246454973 )

# %%
2*t995*x.std()/sqrt(20)
# Out:
# 1.5027101118936261
